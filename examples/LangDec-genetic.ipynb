# %% [markdown]
# # Setup

# %% [markdown]
# 기본적으로 quantization을 적용하고 있어 GPU instance로 접근해야 합니다.

# %%
# !git clone -b genetic https://github.com/yjkim-stat/LangDec.git
# Out:
# Cloning into 'LangDec'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 107 (delta 54), reused 79 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 111.05 KiB | 5.05 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
# !pip3 install torch torchvision torchaudio

# %%
# !pip install -r LangDec/requirements.txt # clone 경로에 맞춰 설정
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 34.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.2/333.2 kB 29.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 129.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 114.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Run scripts

# %% [markdown]
# 결과 저장을 위해 drive mount 이후 진행

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# !pwd
# Out:
# /content

# %% [markdown]
# 실행하기 전에 해당 스크립트 파일을 열어서 환경변수 HF_TOKEN을 설정해야 합니다.

# %%
# !bash ./LangDec/scripts/run_genetic-colab.sh
# Out:
# 2025-11-17 11:40:33.305862: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763379633.338872    5879 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763379633.349012    5879 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763379633.374125    5879 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# # Visualization

# %%
# !pip install pylatexenc
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 14.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=9b516ba18f08c6213307fce20dc2d62a25cde0166eb0ea8e4b69fbe70f222d00
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# ...

# %% [markdown]
# 실험 결과를 불러오기 위한 경로 설정

# %%
# %env GDRIVE_DIR=/content/drive/MyDrive/colab_files
# Out:
# env: GDRIVE_DIR=/content/drive/MyDrive/colab_files

# %% [markdown]
# prefix는 실험한 모델들에 대한 정보이고 마지막에 mathod 명을 추가한다. 현재 method 명의 naming rule은 "$SC_N{MAX_TRIALS}"이고,  실제 폴더명을 확인해보면
# "meta-llama_Llama-3.1-8B-Instruct-UW-Madison-Lee-Lab_VersaPRM-SC_N10"임을 볼 수 있다.
#
# 그래서 method 명을 지정하면, 해당 폴더의 결과를 읽고 결과를 csv와 xlsx 파일로 gdrive에 저장하게 된다.

# %%
# %env EXP_NAME=SC_N10
# Out:
# env: EXP_NAME=SC_N10

# %%
# !python /content/LangDec/main-score.py
# Out:
# Processing ('meta-llama_Llama-3.1-8B-Instruct', 'UW-Madison-Lee-Lab_VersaPRM', 'WMV')
# ============================== Budget (L) 2 - Metric acc ==============================
# Cannot find
# ...
